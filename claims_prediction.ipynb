# %%
import zipfile
import os
import time 
import pandas as pd
import xgboost as xgb
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler

import warnings
warnings.simplefilter('ignore')

# %% [markdown]
# ### Load Dataset

# %%
# Path to the ZIP file containing the training data
df_data = pd.read_csv('datasets/train_set.csv')
df_data.head(10)
# Out:
#    Row_ID  Household_ID  Vehicle  Calendar_Year  Model_Year Blind_Make  \
# 0       1             1        3           2005        2005          K
# 1       2             2        2           2005        2003          Q
# 2       3             3        1           2005        1998         AR
# 3       4             3        1           2006        1998         AR
# 4       5             3        2           2005        2001          D
# 5       6             3        2           2006        2001          D
# 6       7             4        1           2006        2001         AJ
# 7       8             4        2           2006        2002         AQ
# 8       9             4        3           2005        2002         AQ
# 9      10             5        1           2005        1995         BW
#
#   Blind_Model Blind_Submodel Cat1 Cat2  ...      Var5      Var6      Var7  \
# 0        K.78         K.78.2    D    C  ...  1.008912  0.261040  0.907793
# 1        Q.22         Q.22.3    B    C  ...  1.240851  0.432987 -0.726459
# 2       AR.41        AR.41.1    B    ?  ... -0.971487 -1.405797 -0.837048
# 3       AR.41        AR.41.1    B    ?  ... -0.971487 -1.405797 -0.837048
# 4        D.20         D.20.0    J    C  ...  0.812656  2.112691  1.534462
# 5        D.20         D.20.0    J    C  ...  0.812656  2.112691  1.534462
# 6      AJ.129       AJ.129.3    G    C  ...  0.580718  0.551128  0.416289
# 7       AQ.17        AQ.17.1    B    C  ...  0.527193 -0.023200 -0.701884
# 8       AQ.17        AQ.17.1    B    C  ...  0.527193 -0.023200 -0.701884
# 9        BW.3         BW.3.0    D    ?  ...  0.176312  0.283264  0.969232
#
#        Var8 NVCat    NVVar1    NVVar2    NVVar3    NVVar4 Claim_Amount
# 0 -0.077998     M -0.231530 -0.266117 -0.272337 -0.251419          0.0
# 1  0.204785     O -0.231530 -0.266117 -0.272337 -0.251419          0.0
# 2 -1.176858     F -0.231530 -0.266117 -0.272337 -0.251419          0.0
# 3 -1.176858     F -0.231530 -0.266117 -0.272337 -0.251419          0.0
# 4  2.347260     F -0.231530 -0.266117 -0.272337 -0.251419          0.0
# 5  2.347260     F -0.231530 -0.266117 -0.272337 -0.251419          0.0
# 6 -0.024395     M -0.231530 -0.266117 -0.272337 -0.251419          0.0
# 7  0.226663     M -0.231530 -0.266117 -0.272337 -0.251419          0.0
# 8  0.226663     M -0.231530 -0.266117 -0.272337 -0.251419          0.0
# 9 -0.792339     N  2.054683 -0.266117 -0.272337 -0.251419          0.0
#
# [10 rows x 35 columns]

# %%
print(f'Shape of Training data: {df_data.shape}')
print(df_data.columns)
# Out:
# Shape of Training data: (13184290, 35)
# Index(['Row_ID', 'Household_ID', 'Vehicle', 'Calendar_Year', 'Model_Year',
#        'Blind_Make', 'Blind_Model', 'Blind_Submodel', 'Cat1', 'Cat2', 'Cat3',
#        'Cat4', 'Cat5', 'Cat6', 'Cat7', 'Cat8', 'Cat9', 'Cat10', 'Cat11',
#        'Cat12', 'OrdCat', 'Var1', 'Var2', 'Var3', 'Var4', 'Var5', 'Var6',
#        'Var7', 'Var8', 'NVCat', 'NVVar1', 'NVVar2', 'NVVar3', 'NVVar4',
#        'Claim_Amount'],
#       dtype='object')

# %%
# summary statistic of dataset
df_data.describe()
# Out:
#              Row_ID  Household_ID       Vehicle  Calendar_Year    Model_Year  \
# count  1.318429e+07  1.318429e+07  1.318429e+07   1.318429e+07  1.318429e+07
# mean   6.592146e+06  4.128242e+06  1.894002e+00   2.006052e+03  1.999312e+03
# std    3.805977e+06  2.248415e+06  1.173861e+00   8.123720e-01  5.211866e+00
# min    1.000000e+00  1.000000e+00  1.000000e+00   2.005000e+03  1.981000e+03
# 25%    3.296073e+06  2.184932e+06  1.000000e+00   2.005000e+03  1.996000e+03
# 50%    6.592146e+06  4.257083e+06  2.000000e+00   2.006000e+03  2.000000e+03
# 75%    9.888218e+06  6.281433e+06  2.000000e+00   2.007000e+03  2.003000e+03
# max    1.318429e+07  7.542113e+06  2.900000e+01   2.007000e+03  2.009000e+03
#
#                Var1          Var2          Var3          Var4          Var5  \
# count  1.318429e+07  1.318429e+07  1.318429e+07  1.318429e+07  1.318429e+07
# mean  -1.011925e-02 -6.508702e-02 -2.543391e-02 -5.456792e-02  3.838594e-03
# std    9.800609e-01  9.684165e-01  1.018902e+00  9.680170e-01  9.910490e-01
# min   -2.578222e+00 -2.493393e+00 -2.790335e+00 -2.508216e+00 -3.350344e+00
# 25%   -6.658971e-01 -8.161519e-01 -8.696874e-01 -7.830189e-01 -6.860239e-01
# 50%   -3.123581e-01 -1.245062e-01 -2.217581e-01 -1.064709e-01 -1.150981e-01
# 75%    4.429298e-01  4.806838e-01  7.269956e-01  4.855086e-01  5.331405e-01
# max    5.143392e+00  7.829420e+00  5.563325e+00  7.589263e+00  4.018167e+00
#
#                Var6          Var7          Var8        NVVar1        NVVar2  \
# count  1.318429e+07  1.318429e+07  1.318429e+07  1.318429e+07  1.318429e+07
# mean  -4.012271e-02 -2.421288e-02 -5.856059e-02  1.468410e-02  1.751169e-02
# std    9.792078e-01  1.006433e+00  1.003954e+00  1.031040e+00  1.038212e+00
# min   -2.376657e+00 -2.778491e+00 -2.163042e+00 -2.315299e-01 -2.661168e-01
# 25%   -6.887650e-01 -8.984857e-01 -6.517680e-01 -2.315299e-01 -2.661168e-01
# 50%   -2.372568e-01 -4.684193e-01 -2.568567e-01 -2.315299e-01 -2.661168e-01
# 75%    4.973212e-01  8.217801e-01  3.409799e-01 -2.315299e-01 -2.661168e-01
# max    4.584289e+00  4.127148e+00  4.735074e+01  6.627110e+00  8.883081e+00
#
#              NVVar3        NVVar4  Claim_Amount
# count  1.318429e+07  1.318429e+07  1.318429e+07
# mean   1.354226e-02  1.851376e-02  1.360658e+00
# std    1.027748e+00  1.034274e+00  3.900103e+01
# min   -2.723372e-01 -2.514189e-01  0.000000e+00
# 25%   -2.723372e-01 -2.514189e-01  0.000000e+00
# 50%   -2.723372e-01 -2.514189e-01  0.000000e+00
# 75%   -2.723372e-01 -2.514189e-01  0.000000e+00
# max    8.691144e+00  6.388802e+00  1.144075e+04

# %% [markdown]
# ### Preprocessing Data

# %%
# check for missing values 
df_data.isnull().sum()
# Out:
# Row_ID                0
# Household_ID          0
# Vehicle               0
# Calendar_Year         0
# Model_Year            0
# Blind_Make            0
# Blind_Model           0
# Blind_Submodel        0
# Cat1                  0
# Cat2                  0
# Cat3                  0
# Cat4                  0
# Cat5                  0
# Cat6                  0
# Cat7                  0
# Cat8                  0
# Cat9                  0
# Cat10                 0
# Cat11                 0
# Cat12             28882
# OrdCat                0
# Var1                  0
# Var2                  0
# Var3                  0
# Var4                  0
# Var5                  0
# Var6                  0
# Var7                  0
# Var8                  0
# NVCat                 0
# NVVar1                0
# NVVar2                0
# NVVar3                0
# NVVar4                0
# Claim_Amount          0
# dtype: int64

# %%
# We can see that columns 'Cat12' have 28882 missing values, then we can remove these lines 
df_dropped = df_data.dropna(subset=['Cat12'])
df_dropped.shape
# Out:
# (13155408, 35)

# %%
# At this time, our dataset contains columns with text values and columns with numerical values.
# So, we need determine text values columns and encode them to numerical values 

# Determine text value columns 
text_columns = df_dropped.select_dtypes(include=['object']).columns
print(text_columns)
# Out:
# Index(['Blind_Make', 'Blind_Model', 'Blind_Submodel', 'Cat1', 'Cat2', 'Cat3',
#        'Cat4', 'Cat5', 'Cat6', 'Cat7', 'Cat8', 'Cat9', 'Cat10', 'Cat11',
#        'Cat12', 'OrdCat', 'NVCat'],
#       dtype='object')

# %%
# Encode to numerical values 
label_encoders = {}
for col in text_columns:
    le = LabelEncoder()
    df_dropped[col] = le.fit_transform(df_dropped[col].astype(str))
    label_encoders[col] = le
df_dropped.head(10)
# Out:
#    Row_ID  Household_ID  Vehicle  Calendar_Year  Model_Year  Blind_Make  \
# 0       1             1        3           2005        2005          60
# 1       2             2        2           2005        2003          66
# 2       3             3        1           2005        1998          18
# 3       4             3        1           2006        1998          18
# 4       5             3        2           2005        2001          53
# 5       6             3        2           2006        2001          53
# 6       7             4        1           2006        2001          10
# 7       8             4        2           2006        2002          17
# 8       9             4        3           2005        2002          17
# 9      10             5        1           2005        1995          47
#
#    Blind_Model  Blind_Submodel  Cat1  Cat2  ...      Var5      Var6      Var7  \
# 0         1029            2040     4     3  ...  1.008912  0.261040  0.907793
# 1         1141            2263     2     3  ...  1.240851  0.432987 -0.726459
# 2          369             645     2     0  ... -0.971487 -1.405797 -0.837048
# 3          369             645     2     0  ... -0.971487 -1.405797 -0.837048
# 4          917            1760    10     3  ...  0.812656  2.112691  1.534462
# 5          917            1760    10     3  ...  0.812656  2.112691  1.534462
# 6          166             252     7     3  ...  0.580718  0.551128  0.416289
# 7          324             564     2     3  ...  0.527193 -0.023200 -0.701884
# 8          324             564     2     3  ...  0.527193 -0.023200 -0.701884
# 9          820            1597     4     0  ...  0.176312  0.283264  0.969232
#
#        Var8  NVCat    NVVar1    NVVar2    NVVar3    NVVar4  Claim_Amount
# 0 -0.077998     12 -0.231530 -0.266117 -0.272337 -0.251419           0.0
# 1  0.204785     14 -0.231530 -0.266117 -0.272337 -0.251419           0.0
# 2 -1.176858      5 -0.231530 -0.266117 -0.272337 -0.251419           0.0
# 3 -1.176858      5 -0.231530 -0.266117 -0.272337 -0.251419           0.0
# 4  2.347260      5 -0.231530 -0.266117 -0.272337 -0.251419           0.0
# 5  2.347260      5 -0.231530 -0.266117 -0.272337 -0.251419           0.0
# 6 -0.024395     12 -0.231530 -0.266117 -0.272337 -0.251419           0.0
# 7  0.226663     12 -0.231530 -0.266117 -0.272337 -0.251419           0.0
# 8  0.226663     12 -0.231530 -0.266117 -0.272337 -0.251419           0.0
# 9 -0.792339     13  2.054683 -0.266117 -0.272337 -0.251419           0.0
#
# [10 rows x 35 columns]

# %%
# Next, we remove columns 'RowID' , 'Calendar_Year', 'Model_Year' because they are unneccessary for training 
df_train = df_dropped.drop(columns=['Row_ID', 'Calendar_Year', 'Model_Year'])
df_train.head(10)
# Out:
#    Household_ID  Vehicle  Blind_Make  Blind_Model  Blind_Submodel  Cat1  Cat2  \
# 0             1        3          60         1029            2040     4     3
# 1             2        2          66         1141            2263     2     3
# 2             3        1          18          369             645     2     0
# 3             3        1          18          369             645     2     0
# 4             3        2          53          917            1760    10     3
# 5             3        2          53          917            1760    10     3
# 6             4        1          10          166             252     7     3
# 7             4        2          17          324             564     2     3
# 8             4        3          17          324             564     2     3
# 9             5        1          47          820            1597     4     0
#
#    Cat3  Cat4  Cat5  ...      Var5      Var6      Var7      Var8  NVCat  \
# 0     6     0     0  ...  1.008912  0.261040  0.907793 -0.077998     12
# 1     1     1     1  ...  1.240851  0.432987 -0.726459  0.204785     14
# 2     1     1     1  ... -0.971487 -1.405797 -0.837048 -1.176858      5
# 3     1     1     1  ... -0.971487 -1.405797 -0.837048 -1.176858      5
# 4     2     0     0  ...  0.812656  2.112691  1.534462  2.347260      5
# 5     2     0     0  ...  0.812656  2.112691  1.534462  2.347260      5
# 6     1     1     3  ...  0.580718  0.551128  0.416289 -0.024395     12
# 7     2     1     1  ...  0.527193 -0.023200 -0.701884  0.226663     12
# 8     2     1     1  ...  0.527193 -0.023200 -0.701884  0.226663     12
# 9     5     0     0  ...  0.176312  0.283264  0.969232 -0.792339     13
#
#      NVVar1    NVVar2    NVVar3    NVVar4  Claim_Amount
# 0 -0.231530 -0.266117 -0.272337 -0.251419           0.0
# 1 -0.231530 -0.266117 -0.272337 -0.251419           0.0
# 2 -0.231530 -0.266117 -0.272337 -0.251419           0.0
# 3 -0.231530 -0.266117 -0.272337 -0.251419           0.0
# 4 -0.231530 -0.266117 -0.272337 -0.251419           0.0
# 5 -0.231530 -0.266117 -0.272337 -0.251419           0.0
# 6 -0.231530 -0.266117 -0.272337 -0.251419           0.0
# 7 -0.231530 -0.266117 -0.272337 -0.251419           0.0
# 8 -0.231530 -0.266117 -0.272337 -0.251419           0.0
# 9  2.054683 -0.266117 -0.272337 -0.251419           0.0
#
# [10 rows x 32 columns]

# %% [markdown]
# ### Train Test Split

# %%
# Seperate features and target variables
X = df_train.drop(columns=['Claim_Amount'])
y = df_train['Claim_Amount']

# %%
# train-test-split 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
# Transform data 
scaler = StandardScaler()
X_train[X_train.select_dtypes(include=['float64', 'int64']).columns] = scaler.fit_transform(X_train.select_dtypes(include=['float64', 'int64']))
X_test[X_test.select_dtypes(include=['float64', 'int64']).columns] = scaler.transform(X_test.select_dtypes(include=['float64', 'int64']))

# %%
print(X_train.head())
print(X_test.head())
# Out:
#          Household_ID   Vehicle  Blind_Make  Blind_Model  Blind_Submodel  \
# 9113228      0.835029 -0.761609   -0.398455    -0.452342       -0.455564
# 5848934     -0.055140  0.942790   -1.144885    -1.083292       -1.084691
# 5856419     -0.053967  0.090591   -0.178917    -0.281675       -0.274780
# 7679516      0.341432  0.942790   -0.925347    -0.829878       -0.873777
# 5893265     -0.048386  0.942790    0.962681     0.985396        0.923213
#
#              Cat1      Cat2      Cat3      Cat4      Cat5  ...      Var4  \
# 9113228  1.488091  1.063131  2.520346 -0.883644 -0.916517  ...  0.732678
# 5848934 -0.966491 -1.123698  1.242432  0.191392  0.398941  ... -0.403002
# 5856419  0.786782 -0.394755 -0.674440  0.191392  3.029856  ... -0.140922
# 7679516 -0.966491 -1.123698 -0.674440  0.191392  0.398941  ... -0.979578
# 5893265  1.838745  1.063131 -0.035483 -0.883644 -0.916517  ...  0.732678
#
#              Var5      Var6      Var7      Var8     NVCat    NVVar1    NVVar2  \
# 9113228 -0.059824  0.629178  0.584451  0.635184  0.111505 -0.238716 -0.273201
# 5848934  0.318236 -0.353977 -0.929537 -0.767406 -0.974426 -0.238716  1.929829
# 5856419  0.564275  0.792838  0.779804  0.029743  0.835458 -0.238716 -0.273201
# 7679516 -1.164000 -1.234396 -1.185938 -1.261398 -3.508263 -0.238716  2.664172
# 5893265 -0.299863  0.367561  0.437936  1.532985  0.473482 -0.238716  2.664172
#
#            NVVar3    NVVar4
# 9113228 -0.278097 -0.260985
# 5848934 -0.278097 -0.260985
# 5856419 -0.278097 -0.260985
# 7679516  2.631290 -0.260985
# 5893265 -0.278097 -0.260985
#
# [5 rows x 31 columns]
#           Household_ID   Vehicle  Blind_Make  Blind_Model  Blind_Submodel  \
# 12903109      1.437263 -0.761609   -0.969254    -0.871251       -0.901497
# 5376303      -0.190268 -0.761609   -1.232700    -1.109151       -1.125669
# 2733585      -0.973995  0.090591    0.743143     0.739740        0.691810
# 161254       -1.750787  0.090591    1.313942     1.329316        1.425791
# 4636847      -0.610141  5.203786   -0.178917    -0.284261       -0.288038
#
#               Cat1      Cat2     Cat3      Cat4      Cat5  ...      Var4  \
# 12903109 -0.966491 -0.394755 -0.67444  0.191392  0.398941  ... -1.084410
# 5376303   0.436127 -1.123698 -0.67444  2.341465  0.398941  ... -1.468794
# 2733585  -0.265182 -0.394755 -0.67444 -0.883644 -0.916517  ... -0.665082
# 161254   -0.966491  1.063131 -0.67444  0.191392  0.398941  ... -0.752442
# 4636847   1.488091 -0.394755 -0.67444 -0.883644 -0.916517  ...  0.820038
#
#               Var5      Var6      Var7      Var8     NVCat    NVVar1  \
# 12903109 -0.821946 -1.199752 -0.856279 -0.744614 -2.422333 -0.238716
# 5376303  -0.965969 -1.541407 -1.027213 -0.591291 -0.612449 -0.238716
# 2733585   0.702297 -0.146117  0.608870 -0.268506  0.111505 -0.238716
# 161254   -0.617913 -1.046844 -0.953956 -0.619099  0.473482 -0.238716
# 4636847   0.126205  1.308904  1.036205  0.762008  0.111505 -0.238716
#
#             NVVar2    NVVar3    NVVar4
# 12903109 -0.273201 -0.278097 -0.260985
# 5376303  -0.273201 -0.278097  1.342959
# 2733585  -0.273201 -0.278097 -0.260985
# 161254   -0.273201  2.631290 -0.260985
# 4636847  -0.273201 -0.278097 -0.260985
#
# [5 rows x 31 columns]

# %% [markdown]
# ### XGBoost Regressor Training

# %%
params = {
    'objective':'reg:squarederror', 
    'colsample_bytree': 0.3, 
    'learning_rate': 0.1,
    'max_depth': 10, 
    'alpha':10, 
    'n_estimators': 1000
}

# Initialize XGBoost Regressor model 
xgb_reg = xgb.XGBRegressor(**params)

training_start = time.perf_counter() 

# Training 
xgb_reg.fit(X_train, y_train) 


training_end = time.perf_counter() 
xgb_training_time = training_end - training_start
print(f'Time consumed for training: {xgb_training_time}')
# Out:
# Time consumed for training: 207.54574995900475

# %% [markdown]
# ### Prediction

# %%
y_pred = xgb_reg.predict(X_test)

# %%
xgb_rmse = mean_squared_error(y_test, y_pred, squared=False) 
xgb_r2_socre = r2_score(y_test, y_pred)

print(f'Mean Square Error when used XGBoost Regressor: {xgb_rmse}')
print(f'R2 Score when used XGBoost Regressor: {xgb_r2_socre}')
# Out:
# Mean Square Error when used XGBoost Regressor: 38.48506757595425
# R2 Score when used XGBoost Regressor: -0.01688787615871523
